# %% [markdown]
# # Code Testing Ground

# %%
animals = {
    'cat': 'kitten',
    'dog': 'puppy',
    'cow': 'calf',
    'horse': 'foal',
    'sheep': 'lamb',
    'goat': 'kid',
    'pig': 'piglet',
    'duck': 'duckling',
    'chicken': 'chick',
    'goose': 'gosling',
    'deer': 'fawn',
    'lion': 'cub',
    'tiger': 'cub',
    'bear': 'cub',
    'elephant': 'calf',
    'kangaroo': 'joey',
    'rabbit': 'bunny',
    'fox': 'kit',
    'owl': 'owlet',
    'swan': 'cygnet',
    'snake': 'hatchling',
    'frog': 'tadpole',
    'toad': 'tadpole',
    'fish': 'fry',
    'whale': 'calf',
    'dolphin': 'calf',
    'shark': 'pup',
    'seal': 'pup',
    'otter': 'pup',
    'bat': 'pup',
    'camel': 'calf',
    'giraffe': 'calf',
    'hippo': 'calf',
    'alpaca': 'cria',
    'llama': 'cria',
    'turkey': 'poult',
    'eagle': 'eaglet',
    'parrot': 'chick',
    'mouse': 'pinky',
    'rat': 'pup'
}

# %%
for animal, baby in animals.items():
    print(f"{animal:.<10}: {baby}")
# Out:
# cat.......: kitten
# dog.......: puppy
# cow.......: calf
# horse.....: foal
# sheep.....: lamb
# goat......: kid
# pig.......: piglet
# duck......: duckling
# chicken...: chick
# goose.....: gosling
# deer......: fawn
# lion......: cub
# tiger.....: cub
# bear......: cub
# elephant..: calf
# kangaroo..: joey
# rabbit....: bunny
# fox.......: kit
# owl.......: owlet
# swan......: cygnet
# snake.....: hatchling
# frog......: tadpole
# toad......: tadpole
# fish......: fry
# whale.....: calf
# dolphin...: calf
# shark.....: pup
# seal......: pup
# otter.....: pup
# bat.......: pup
# camel.....: calf
# giraffe...: calf
# hippo.....: calf
# alpaca....: cria
# llama.....: cria
# turkey....: poult
# eagle.....: eaglet
# parrot....: chick
# mouse.....: pinky
# rat.......: pup

# %%
flowers = {
    'rose': 'bud',
    'tulip': 'bud',
    'sunflower': 'seedling',
    'orchid': 'bud',
    'lily': 'bud',
    'daisy': 'bud',
    'marigold': 'seedling',
    'hibiscus': 'bud',
    'lotus': 'bud',
    'chrysanthemum': 'bud',
    'lavender': 'seedling',
    'peony': 'bud',
    'jasmine': 'bud',
    'daffodil': 'bud',
    'iris': 'bud',
    'poppy': 'bud',
    'magnolia': 'bud',
    'geranium': 'seedling',
    'petunia': 'seedling',
    'carnation': 'bud'
}

# %%
for flower, seed in animals.items():
    print(f"{flower:.<10}: {seed}")
# Out:
# cat.......: kitten
# dog.......: puppy
# cow.......: calf
# horse.....: foal
# sheep.....: lamb
# goat......: kid
# pig.......: piglet
# duck......: duckling
# chicken...: chick
# goose.....: gosling
# deer......: fawn
# lion......: cub
# tiger.....: cub
# bear......: cub
# elephant..: calf
# kangaroo..: joey
# rabbit....: bunny
# fox.......: kit
# owl.......: owlet
# swan......: cygnet
# snake.....: hatchling
# frog......: tadpole
# toad......: tadpole
# fish......: fry
# whale.....: calf
# dolphin...: calf
# shark.....: pup
# seal......: pup
# otter.....: pup
# bat.......: pup
# camel.....: calf
# giraffe...: calf
# hippo.....: calf
# alpaca....: cria
# llama.....: cria
# turkey....: poult
# eagle.....: eaglet
# parrot....: chick
# mouse.....: pinky
# rat.......: pup

# %%
animals_cn = {
    'cat': '猫',
    'dog': '狗',
    'cow': '牛',
    'horse': '马',
    'sheep': '羊',
    'goat': '山羊',
    'pig': '猪',
    'duck': '鸭',
    'chicken': '鸡',
    'goose': '鹅',
    'deer': '鹿',
    'lion': '狮子',
    'tiger': '老虎',
    'bear': '熊',
    'elephant': '大象',
    'kangaroo': '袋鼠',
    'rabbit': '兔子',
    'fox': '狐狸',
    'owl': '猫头鹰',
    'swan': '天鹅',
    'snake': '蛇',
    'frog': '青蛙',
    'toad': '蟾蜍',
    'fish': '鱼',
    'whale': '鲸鱼',
    'dolphin': '海豚',
    'shark': '鲨鱼',
    'seal': '海豹',
    'otter': '水獭',
    'bat': '蝙蝠',
    'camel': '骆驼',
    'giraffe': '长颈鹿',
    'hippo': '河马',
    'alpaca': '羊驼',
    'llama': '美洲驼',
    'turkey': '火鸡',
    'eagle': '老鹰',
    'parrot': '鹦鹉',
    'mouse': '老鼠',
    'rat': '大鼠'
}
for animal, animal_cn in animals_cn.items():
    print(f"{animal:.<10}: {animal_cn}")
# Out:
# cat.......: 猫
# dog.......: 狗
# cow.......: 牛
# horse.....: 马
# sheep.....: 羊
# goat......: 山羊
# pig.......: 猪
# duck......: 鸭
# chicken...: 鸡
# goose.....: 鹅
# deer......: 鹿
# lion......: 狮子
# tiger.....: 老虎
# bear......: 熊
# elephant..: 大象
# kangaroo..: 袋鼠
# rabbit....: 兔子
# fox.......: 狐狸
# owl.......: 猫头鹰
# swan......: 天鹅
# snake.....: 蛇
# frog......: 青蛙
# toad......: 蟾蜍
# fish......: 鱼
# whale.....: 鲸鱼
# dolphin...: 海豚
# shark.....: 鲨鱼
# seal......: 海豹
# otter.....: 水獭
# bat.......: 蝙蝠
# camel.....: 骆驼
# giraffe...: 长颈鹿
# hippo.....: 河马
# alpaca....: 羊驼
# llama.....: 美洲驼
# turkey....: 火鸡
# eagle.....: 老鹰
# parrot....: 鹦鹉
# mouse.....: 老鼠
# rat.......: 大鼠

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# --- Sample time-series data ---
dates = pd.date_range(start="2024-01-01", periods=12, freq="M")
sales = np.random.randint(100, 300, size=12)      # Left axis
customers = np.random.randint(1000, 5000, size=12) # Right axis

# Create a DataFrame
df = pd.DataFrame({
    "date": dates,
    "sales": sales,
    "customers": customers
})

# --- Plot with two y-axes ---
fig, ax1 = plt.subplots(figsize=(10, 5))

# Left axis
ax1.plot(df["date"], df["sales"], marker="o", linewidth=2)
ax1.set_xlabel("Month")
ax1.set_ylabel("Sales (Units)", color="blue")
ax1.tick_params(axis='y', labelcolor='blue')

# Right axis
ax2 = ax1.twinx()  # <- Creates second y-axis
ax2.plot(df["date"], df["customers"], marker="s", linestyle="--")
ax2.set_ylabel("Customers Count", color="red")
ax2.tick_params(axis='y', labelcolor='red')

plt.grid()

plt.title("Sales vs Customers Over Time (Two Y-Axes)")
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# --- Create 12 months of data ---
dates = pd.date_range(start="2024-01-01", end="2024-12-31", freq="MS")
sales = np.random.randint(100, 300, size=12)
customers = np.random.randint(1000, 5000, size=12)

df = pd.DataFrame({
    "date": dates,
    "sales": sales,
    "customers": customers
})

# --- Plot ---
fig, ax1 = plt.subplots(figsize=(12, 5))

# Left y-axis
ax1.plot(df["date"], df["sales"], marker="o", linewidth=2, label="Sales")
ax1.set_ylabel("Sales", color="blue")
ax1.tick_params(axis='y', labelcolor='blue')

# Right y-axis
ax2 = ax1.twinx()
ax2.plot(df["date"], df["customers"], marker="s", linestyle="--",
         color="red", label="Customers")
ax2.set_ylabel("Customers", color="red")
ax2.tick_params(axis='y', labelcolor='red')

# --- X-axis ticks: show every month ---
plt.xticks(df["date"], df["date"].dt.strftime("%Y-%m"), rotation=45)

plt.grid()
plt.title("Sales vs Customers (One Full Year, Monthly)")
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# --- Generate sample monthly data ---
dates = pd.date_range(start="2024-01-01", periods=12, freq="MS")

# Create a clear peak for demonstration
sales = np.array([120, 150, 180, 200, 250, 300, 450, 280, 260, 220, 210, 190])
customers = np.random.randint(1500, 5000, size=12)

df = pd.DataFrame({
    "date": dates,
    "sales": sales,
    "customers": customers
})

# --- Find top peak ---
peak_idx = df["sales"].idxmax()
peak_date = df.loc[peak_idx, "date"]
peak_value = df.loc[peak_idx, "sales"]

# --- Plot ---
fig, ax1 = plt.subplots(figsize=(12, 5))

# Left y-axis (Sales)
ax1.plot(df["date"], df["sales"], marker="o", linewidth=2, label="Sales")
ax1.set_ylabel("Sales", color="blue")
ax1.tick_params(axis='y', labelcolor='blue')

# Highlight the peak month
ax1.scatter(peak_date, peak_value, color="red", s=120, zorder=5)
ax1.annotate(
    "Top Sales",
    xy=(peak_date, peak_value),
    xytext=(0, 15),
    textcoords="offset points",
    ha="center",
    color="red",
    fontsize=12,
    fontweight="bold"
)

# Right y-axis (Customers)
ax2 = ax1.twinx()
ax2.plot(df["date"], df["customers"], marker="s", linestyle="--", color="green", label="Customers")
ax2.set_ylabel("Customers", color="green")
ax2.tick_params(axis='y', labelcolor='green')

# X-axis ticks (every month)
plt.xticks(df["date"], df["date"].dt.strftime("%Y-%m"), rotation=45)

plt.title("Sales vs Customers (Highlight Top Peak Month)")
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# --- Generate sample monthly data ---
dates = pd.date_range(start="2024-01-01", periods=12, freq="MS")

# Create a clear peak for demonstration
sales = np.array([120, 150, 180, 200, 250, 300, 750, 280, 260, 220, 210, 190])
customers = np.random.randint(1500, 5000, size=12)

df = pd.DataFrame({
    "date": dates,
    "sales": sales,
    "customers": customers
})

# --- Find top peak ---
peak_idx = df["sales"].idxmax()
peak_date = df.loc[peak_idx, "date"]
peak_value = df.loc[peak_idx, "sales"]

# --- Plot ---
fig, ax1 = plt.subplots(figsize=(12, 5))

# Left y-axis (Sales)
ax1.plot(df["date"], df["sales"], marker="o", linewidth=2, label="Sales")
ax1.set_ylabel("Sales", color="blue")
ax1.tick_params(axis='y', labelcolor='blue')

# Highlight the peak month
ax1.scatter(peak_date, peak_value, color="red", s=120, zorder=5)
ax1.annotate(
    "Top Sales",
    xy=(peak_date, peak_value),
    xytext=(0, -20),             # ← move label BELOW the dot
    textcoords="offset points",
    ha="center",
    va="top",                    # ← align text above its anchor
    color="red",
    fontsize=12,
    fontweight="bold"
)

# Right y-axis (Customers)
ax2 = ax1.twinx()
ax2.plot(df["date"], df["customers"], marker="s", linestyle="--",
         color="green", label="Customers")
ax2.set_ylabel("Customers", color="green")
ax2.tick_params(axis='y', labelcolor='green')

# X-axis ticks (every month)
plt.xticks(df["date"], df["date"].dt.strftime("%Y-%m"), rotation=45)

plt.grid()
plt.title("Sales vs Customers (Highlight Top Peak Month - Label Below Dot)")
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# --- Create sample data ---
dates = pd.date_range(start="2024-01-01", periods=12, freq="MS")

sales = np.array([120, 150, 180, 200, 250, 300, 450, 280, 260, 220, 210, 190])
customers = np.random.randint(1500, 5000, size=12)

df = pd.DataFrame({
    "date": dates,
    "sales": sales,
    "customers": customers
})

# Identify peak sales
peak_idx = df["sales"].idxmax()
peak_date = df.loc[peak_idx, "date"]
peak_value = df.loc[peak_idx, "sales"]

# --- Plot with seaborn ---
sns.set_style("whitegrid")

fig, ax1 = plt.subplots(figsize=(12, 5))

# Left axis: Sales
sns.lineplot(data=df, x="date", y="sales", marker="o", ax1=ax1, color="blue")
ax1.set_ylabel("Sales", color="blue")
ax1.tick_params(axis="y", labelcolor="blue")

# Highlight the peak sales dot
ax1.scatter(peak_date, peak_value, s=120, color="red", zorder=5)

# Put label *below* the dot
ax1.annotate(
    "Top Sales",
    xy=(peak_date, peak_value),
    xytext=(0, -20),
    textcoords="offset points",
    ha="center",
    va="top",
    fontsize=12,
    color="red",
    fontweight="bold"
)

# Right axis: Customers
ax2 = ax1.twinx()
sns.lineplot(data=df, x="date", y="customers", marker="s", linestyle="--", ax=ax2, color="green")
ax2.set_ylabel("Customers", color="green")
ax2.tick_params(axis="y", labelcolor="green")

# X-axis formatting
plt.xticks(df["date"], df["date"].dt.strftime("%Y-%m"), rotation=45)

plt.title("Seaborn: Sales vs Customers (Peak Highlighted)")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 29
#      26 fig, ax1 = plt.subplots(figsize=(12, 5))
#      28 # Left axis: Sales
# ---> 29 sns.lineplot(data=df, x="date", y="sales", marker="o", ax1=ax1, color="blue")
#      30 ax1.set_ylabel("Sales", color="blue")
#      31 ax1.tick_params(axis="y", labelcolor="blue")
#
# File /opt/anaconda3/lib/python3.12/site-packages/seaborn/relational.py:515, in lineplot(data, x, y, hue, size, style, units, weights, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     512 color = kwargs.pop("color", kwargs.pop("c", None))
#     513 kwargs["color"] = _default_color(ax.plot, hue, color, kwargs)
# --> 515 p.plot(ax, kwargs)
#     516 return ax
#
# File /opt/anaconda3/lib/python3.12/site-packages/seaborn/relational.py:316, in _LinePlotter.plot(self, ax, kws)
#     314         lines.extend(ax.plot(unit_data["x"], unit_data["y"], **kws))
#     315 else:
# --> 316     lines = ax.plot(sub_data["x"], sub_data["y"], **kws)
#     318 for line in lines:
#     320     if "hue" in sub_vars:
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/axes/_axes.py:1779, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1536 """
#    1537 Plot y versus x as lines and/or markers.
#    1538
#    (...)
#    1776 (``'green'``) or hex strings (``'#008000'``).
#    1777 """
#    1778 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1779 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1780 for line in lines:
#    1781     self.add_line(line)
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/axes/_base.py:296, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     294     this += args[0],
#     295     args = args[1:]
# --> 296 yield from self._plot_args(
#     297     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/axes/_base.py:534, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     532     return list(result)
#     533 else:
# --> 534     return [l[0] for l in result]
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/axes/_base.py:527, in <genexpr>(.0)
#     522 else:
#     523     raise ValueError(
#     524         f"label must be scalar or have the same length as the input "
#     525         f"data, but found {len(label)} for {n_datasets} datasets.")
# --> 527 result = (make_artist(axes, x[:, j % ncx], y[:, j % ncy], kw,
#     528                       {**kwargs, 'label': label})
#     529           for j, label in enumerate(labels))
#     531 if return_kwargs:
#     532     return list(result)
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/axes/_base.py:335, in _process_plot_var_args._makeline(self, axes, x, y, kw, kwargs)
#     333 kw = {**kw, **kwargs}  # Don't modify the original kw.
#     334 self._setdefaults(self._getdefaults(kw), kw)
# --> 335 seg = mlines.Line2D(x, y, **kw)
#     336 return seg, kw
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/lines.py:407, in Line2D.__init__(self, xdata, ydata, linewidth, linestyle, color, gapcolor, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     403 self.set_markeredgewidth(markeredgewidth)
#     405 # update kwargs before updating data to give the caller a
#     406 # chance to init axes (and hence unit support)
# --> 407 self._internal_update(kwargs)
#     408 self.pickradius = pickradius
#     409 self.ind_offset = 0
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/artist.py:1216, in Artist._internal_update(self, kwargs)
#    1209 def _internal_update(self, kwargs):
#    1210     """
#    1211     Update artist properties without prenormalizing them, but generating
#    1212     errors as if calling `set`.
#    1213
#    1214     The lack of prenormalization is to maintain backcompatibility.
#    1215     """
# -> 1216     return self._update_props(
#    1217         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1218         "{prop_name!r}")
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/artist.py:1190, in Artist._update_props(self, props, errfmt)
#    1188             func = getattr(self, f"set_{k}", None)
#    1189             if not callable(func):
# -> 1190                 raise AttributeError(
#    1191                     errfmt.format(cls=type(self), prop_name=k))
#    1192             ret.append(func(v))
#    1193 if ret:
#
# AttributeError: Line2D.set() got an unexpected keyword argument 'ax1'

# %%
print("---End---")
# Out:
# ---End---
